# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm_notebook
from tqdm import tqdm_notebook
from matplotlib import animation
from IPython.display import HTML

# %%
check = 0.75
A = 0.025
LENGTH = 5
DURATION = 500
INITIAL = 0
BOUND = 0.5

NUMBER_X = 101
NUMBER_T = int(A * DURATION * NUMBER_X / check / LENGTH)

# %%
step_x = LENGTH / (NUMBER_X - 1)
step_t = DURATION / (NUMBER_T - 1)

# %%
axis = np.linspace(0, LENGTH, NUMBER_X)
time = np.linspace(0, DURATION, NUMBER_T)

function = pd.DataFrame(columns = np.concatenate([['x'], time]))

# %%
function['x'] = axis

# %%
function.iloc[:,0] = INITIAL
function.iloc[0] = BOUND
function.iloc[NUMBER_X-1,:] = INITIAL

# %%
delta_t = time.max()
check = A * step_t / step_x
if check > 1:
    print('ALARM! Make A smaller')

# %%
def smooth(f, x, t):
    q = 0
    dmm = f.iloc[x-1, t+1] - f.iloc[x-2, t+1]
    dm = f.iloc[x, t+1] - f.iloc[x-1, t+1]
    dp = f.iloc[x+1, t+1] - f.iloc[x, t+1]
    dpp = f.iloc[x+2, t+1] - f.iloc[x+1, t+1]
    
    if (dpp * dp < 0) or (dm * dp < 0):
        q_plus = dp
    else:
        q_plus = 0
        
    if (dmm * dm < 0) or (dm * dp < 0):
        q_minus = dm
    else:
        q_minus = 0   
        
    return f.iloc[x, t+1] + q * (q_plus - q_minus)

# %%
pbar = tqdm_notebook(total = NUMBER_T)

for t in range(0, NUMBER_T):
    for x in range(1, NUMBER_X - 1):
        f_plus = 0.5 * ((function.iloc[x+1,t] + function.iloc[x,t]) - 
                        check * 0.5 * (np.power(function.iloc[x+1,t],2) - np.power(function.iloc[x,t], 2)))
        
        f_minus = 0.5 * ((function.iloc[x,t] + function.iloc[x-1,t]) - 
                        check * 0.5 * (np.power(function.iloc[x,t], 2) - np.power(function.iloc[x-1,t], 2)))
        
        function.iloc[x,t+1] = function.iloc[x,t] - check * 0.5 * (np.power(f_plus, 2) - np.power(f_minus,2))
        
    for x in range(2, NUMBER_X - 2):
        function.iloc[x,t+1] = smooth(function,x,t)
        
    pbar.update()
# Out:
# HBox(children=(IntProgress(value=0, max=336), HTML(value='')))

# %%
plt.rcParams.update({'font.size': 15})
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
plt.rc('text.latex', preamble=r'\usepackage[utf8]{inputenc}')
plt.rc('text.latex', preamble=r'\usepackage[english]{babel}')

fig, ax = plt.subplots(figsize=(10, 5))
ax.axis([-0.1, LENGTH + 0.01, -0.1, BOUND + 0.2])

l1, = ax.plot(function.index * LENGTH / NUMBER_X, function.iloc[:, NUMBER_T], lw=3, color='black', label=NUMBER_T)

ax.grid(c='#aaaaaa', ls='--')

ax.set_ylabel("f(x)")
ax.set_xlabel("x")

def animate(i):
    l1.set_data(function.index * LENGTH / NUMBER_X, function.iloc[:, i])
    l1.set_label('t = ' + str(i * step_t))

    legend = plt.legend(loc='upper right')
    return l1, legend

ani = animation.FuncAnimation(fig, animate, frames= np.arange(0, NUMBER_T, 5), interval=100)

# ani.save("movie.mp4")
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgc70301f2a45a4efab30f277f2a8cba1a">
#     <br>
#     <input id="_anim_sliderc70301f2a45a4efab30f277f2a8cba1a" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="animc70301f2a45a4efab30f277f2a8cba1a.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animc70301f2a45a4efab30f277f2a8cba1a.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="animc70301f2a45a4efab30f277f2a8cba1a.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="animc70301f2a45a4efab30f277f2a8cba1a.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="animc70301f2a45a4efab30f277f2a8cba1a.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="animc70301f2a45a4efab30f277f2a8cba1a.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="animc70301f2a45a4efab30f277f2a8cba1a.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="animc70301f2a45a4efab30f277f2a8cba1a.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="animc70301f2a45a4efab30f277f2a8cba1a.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="animc70301f2a45a4efab30f277f2a8cba1a.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_selectc70301f2a45a4efab30f277f2a8cba1a" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgc70301f2a45a4efab30f277f2a8cba1a";
#     var slider_id = "_anim_sliderc70301f2a45a4efab30f277f2a8cba1a";
#     var loop_select_id = "_anim_loop_selectc70301f2a45a4efab30f277f2a8cba1a";
#     var frames = new Array(68);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDMuMC4zLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvnQurowAAIABJREFUeJzt3c9vFHl+//FXG/NrlvUUNjPADl/Q\
# NJYILAGt3fwQCDRA9yFRTht7JrcoUmJyyCnaxRrlktNa9MwfMN3sYa879ua2h8htICAQ4HbPDiIQ\
# ElM7EEaGGWxXzA8bsN3fA+paG/8o12C76k0/H9JKpim3P/Ckd94uf7oqUS6XywIAAACwIDVRLwAA\
# AACwhAEaAAAACIEBGgAAAAiBARoAAAAIgQEaAAAACIEBGgAAAAiBARoAAAAIgQEaAAAACIEBGgAA\
# AAiBARoAAAAIgQEaAAAACIEBGgAAAAiBARoAAAAIgQEaAAAACIEBGgAAAAiBARoAAAAIgQEaAAAA\
# CIEBGgAAAAiBARoAAAAIgQEaAAAACIEBGgAAAAiBARoAAAAIgQEaAAAACIEBGgAAAAiBARoAAAAI\
# gQEaAAAACIEBGgAAAAiBARoAAAAIgQEaAAAACIEBGgAAAAiBARoAAAAIgQEaAAAACIEBGgAAAAiB\
# ARoAAAAIgQEaAAAACIEBGgAAAAiBARoAAAAIgQEaAAAACIEBWpLnecpms+rq6lI2m1WpVJrz2NbW\
# Vrmuu4yrAwAAQJwkyuVyOepFRC2TySiXyymZTPq/7uzslOM4M45NJBIzHksmk7pz586SrxMAAADR\
# q/oz0J7nyXVdf3iWXg3EhUJh1mNzuZzK5bL/v+7ubnV2di7nkgEAABChqh+gi8XijDPNjuOou7t7\
# xrGO46itrc3/ted58jxPTU1NS75OAAAAxENt1AuImud5qq+vn/ZYQ0PDgvY5d3R06PTp03P+fj6f\
# Vz6flyTdunVLH3zwgSRpzZo1qqmp0bNnzyRJtbW1eueddzQyMiJJKpfLevfdd/X06VNNTExIktat\
# W6eXL1/q+fPnsz7HypUrtWbNGj1+/FiSVFNTo3Xr1s14jhcvXujFixeSpLVr10qSRkdH532OJ0+e\
# aHJyUpL04x//WGNjY3r58uWsz7Fq1SqtWrVKT548kSStWLFCP/rRj+Z9jnfeeUeTk5MaGxuTJK1e\
# vVorV66c8RyPHz9WZcdRXV2dnj17pvHx8Tmfo7a2Vk+fPp32d1x5jkQioR//+MfTnuNHP/qRxsfH\
# 5/w7fr1T5TmePn2q8fFxJRIJOsW809S/49HRUf/XdIpvp9dfTxMTE/6flU7x7TT1OWpqavw/C53i\
# 22nq33G5XNbw8LAePXokzK7qB2hJGhoaCv05XV1d2rdv37zHtLW1+WesU6mUisXigp772bNneued\
# d0KvCdGhmT00s4lu9tDMnmfPnuno0aNRLyPWqn4Lh+M48jxv2mODg4Mzzkq/rqOjQ+l0eknWdO/e\
# vSV5XiwdmtlDM5voZg/N7KFZsKofoFOp1Iwz0J7nKZPJzPk5nuepVCrNepWOxXD//v0leV4sHZrZ\
# QzOb6GYPzeyhWbCqH6Adx1EqlZq257lYLPpnl13XnbEferY3HgIAAKA6sAdaUmdnp/L5vJLJpFzX\
# 1ZkzZ/wBOZfL+ZevmyqVSi3Zenbt2rVkz42lQTN7aGYT3eyhmT00C8YArVdnoU+dOjXr7812lY10\
# Or1k+5+lV+8uhi00s4dmNtHNHprZQ7Ng/A3F0I0bN6JeAkKimT00s4lu9tDMHpoF4ww0AABYNiMj\
# I/ruu+/8ay1j+a1cuVLvv/++6urqol6KWQzQMbR58+aol4CQaGYPzWyimz1Tm42MjOjhw4f64IMP\
# tHbtWiUSiQhXVp3K5bJGR0f17bffStKsQzSvs2Bs4YihxsbGqJeAkGhmD81sops9U5t99913+uCD\
# D/TOO+8wPEckkUjonXfe0QcffKDvvvtu1mN4nQVjgI6hixcvRr0EhEQze2hmE93s

# %%
# fig, ax = plt.subplots(figsize=(10, 5))
# plt.figure(figsize=(25,15))
# plt.rcParams.update({'font.size': 20})
# plt.rc('text', usetex=True)
# plt.rc('font', family='serif')
# plt.rc('text.latex', preamble=r'\usepackage[utf8]{inputenc}')
# plt.rc('text.latex', preamble=r'\usepackage[english]{babel}')

# ax.plot(function.index * LENGTH / NUMBER_X,function.iloc[:,1001], label="100", c='black')
