# %% [markdown]
# # Transport equation

# %% [markdown]
# ## libs

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm_notebook
from matplotlib import animation
from IPython.display import HTML

# %% [markdown]
# ## initialization

# %%
check = 0.75

# %%
A = 0.5
LENGTH = 10
DURATION = 25
INITIAL = 0
BOUND = 5

NUMBER_X = 101
NUMBER_T = int(A * DURATION * NUMBER_X / check / LENGTH)

# %%
step_x = LENGTH / (NUMBER_X - 1)
step_t = DURATION / (NUMBER_T - 1)

# %%
axis = np.linspace(0, LENGTH, NUMBER_X)
time = np.linspace(0, DURATION, NUMBER_T)

function = pd.DataFrame(columns = np.concatenate([['x'], time]))

# %%
function['x'] = axis
function = function.set_index('x')

# %%
function.iloc[:, 0] = INITIAL
function.iloc[0] = BOUND
function.iloc[NUMBER_X-1, :] = INITIAL

# %% [markdown]
# ## main procedure

# %%
pbar = tqdm_notebook(total = NUMBER_T - 1)

for t in range(0, NUMBER_T - 1):
    for x in range(1, NUMBER_X - 1):
        function.iloc[x, t+1] = 0.5 * (function.iloc[x+1, t] + function.iloc[x-1, t] - 
                                      check * (function.iloc[x+1, t] - function.iloc[x-1, t]))
    pbar.update()
# Out:
# HBox(children=(IntProgress(value=0, max=167), HTML(value='')))

# %% [markdown]
# ## animated plot

# %%
plt.rcParams.update({'font.size': 15})
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
plt.rc('text.latex', preamble=r'\usepackage[utf8]{inputenc}')
plt.rc('text.latex', preamble=r'\usepackage[english]{babel}')

fig, ax = plt.subplots(figsize=(10, 5))
ax.axis([-0.1, LENGTH + 0.1, -0.1, BOUND + 1.1])

l1, = ax.plot(function.index, function.iloc[:, NUMBER_T - 1], lw=3, color='black', label=NUMBER_T)
l2, = ax.plot([ A * float(function.columns[20]), A * float(function.columns[20])],[0, BOUND], lw=3, color='blue', label=None)

ax.grid(c='#aaaaaa', ls='--')

ax.set_ylabel("f(x)")
ax.set_xlabel("x")

def animate(i):
    l1.set_data(function.index, function.iloc[:, i])
    l1.set_label('t = ' + '%.3f' % (i * step_t))
    l2.set_data([A * float(function.columns[i+1]), A * float(function.columns[i+1])],[0, BOUND])

    legend = plt.legend(loc='upper right')
    return l1, l2, legend

ani = animation.FuncAnimation(fig, animate, frames= np.arange(0, NUMBER_T, 5), interval=50)

#ani.save("solution.mp4")
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img2ef206fe4b9d4c9081e13433672f1be1">
#     <br>
#     <input id="_anim_slider2ef206fe4b9d4c9081e13433672f1be1" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim2ef206fe4b9d4c9081e13433672f1be1.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim2ef206fe4b9d4c9081e13433672f1be1.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim2ef206fe4b9d4c9081e13433672f1be1.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim2ef206fe4b9d4c9081e13433672f1be1.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim2ef206fe4b9d4c9081e13433672f1be1.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim2ef206fe4b9d4c9081e13433672f1be1.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim2ef206fe4b9d4c9081e13433672f1be1.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim2ef206fe4b9d4c9081e13433672f1be1.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim2ef206fe4b9d4c9081e13433672f1be1.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim2ef206fe4b9d4c9081e13433672f1be1.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select2ef206fe4b9d4c9081e13433672f1be1" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img2ef206fe4b9d4c9081e13433672f1be1";
#     var slider_id = "_anim_slider2ef206fe4b9d4c9081e13433672f1be1";
#     var loop_select_id = "_anim_loop_select2ef206fe4b9d4c9081e13433672f1be1";
#     var frames = new Array(34);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDMuMC4zLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvnQurowAAIABJREFUeJzt3V9TlGee//FPg0ZIUZ0W2IgZAskN\
# Va7GxU3ToqWlpdKczMEezGLyAHYH9gHMmMrZ7MlakjyAgPPb8wR2T6embNTS1VVpOqOxZJlgl/8S\
# dAawp8NENEL/Dty+A4rEq/1z9Xd5v6pS1XYDXjNvW79cXH13pFAoFAQAAADgmVT4XgAAAABgCQM0\
# AAAA4IABGgAAAHDAAA0AAAA4YIAGAAAAHDBAAwAAAA4YoAEAAAAHDNAAAACAAwZoAAAAwAEDNAAA\
# AOCAARoAAABwwAANAAAAOGCABgAAABwwQAMAAAAOGKABAAAABwzQAAAAgAMGaAAAAMABAzQAAADg\
# gAEaAAAAcMAADQAAADhggAYAAAAcMEADAAAADhigAQAAAAcM0AAAAIADBmgAAADAAQM0AAAA4IAB\
# GgAAAHDAAA0AAAA4YIAGAAAAHDBAAwAAAA4YoAEAAAAHDNAAAACAAwZoAAAAwAEDNAAAAOCAARoA\
# AABwwAANAAAAOGCABgAAABwwQAMAAAAOGKABAAAABwzQAAAAgAMGaAAAAMABAzQAAADgYI3vBViV\
# yWSUSqUUBIFmZmbU09Oz4sfX19frnXfeWXLf/fv3tW7dupe4SrwMdLOHZjbRzR6a2bRct2vXrmlq\
# asrTisofA3QJMpmMDh8+rMHBQUlSe3u7EomE4vH4Uz/nnXfeUTqdXnLf999/r9dff/2lrhUvHt3s\
# oZlNdLOHZjYt1y2RSHhajQ0c4SjBL3/5Sx05ciT89fDw8IrD89PcuHHjRS4Lrwjd7KGZTXSzh2Y2\
# 0c0dA7SjXC6nTCajIAiUyWSUzWYVi8VK+lq3bt16wavDq0A3e2hmE93soZlNdHPHAO0onU4rCAIN\
# DQ0pCAJls1n19vb6XhYAAABeEc5AO8rlcspms0omk4rFYkomkzpy5IiGhobU3d295GMHBgY0MDAg\
# SZqcnFQqlZIktba2KhqN6sGDB0qlUqqvr1dbW5uOHz8uSaqsrNT+/ft14cIF5fN5SdKOHTt0+/Zt\
# Xb9+XZK0adMmVVVV6eLFi5KkDRs2aPPmzTp58qQk6bXXXtPevXt17tw5zc7OSpJ27dqlGzduhN9p\
# btmyRRUVFbp8+bIkaePGjWptbdXp06clSdXV1dq9e7fOnDmje/fuSZL27NmjiYkJTU5OSpK2bt2q\
# hYUFXblyRZLU2NiopqYmnT17VpJUU1OjnTt36tSpU3rw4IEkad++fRobG9OdO3ckSdu2bdPc3JzG\
# x8clSc3NzWpoaND58+clSdFoVB0dHTpx4oTm5+clSQcOHNClS5fCFzjE43Hl83lNTExIkoIgUF1d\
# nUZGRiRJ69evV3t7u4aHh1UoFBSJRNTZ2anR0VHdvXtXkrR9+3ZNT08rm80u6ZTJZCQp7FTsRqfy\
# 7rT4+bRlyxY6Gej0+PPp3Xff1ddff02nMu+0+Pn04MED3bx5k05l3kla+nx68OCBvvrqqyWdsLJI\
# oVAo+F6EJZlMRp2dneEfaknhDnR/f/9TPy+RSDzxIsLbt2+roaHh5SwULw3d7KGZTXSzh2Y2Lddt\
# ubkFP+IIh6MgCJTL5Z64v5Rz0MXvrGEL3eyhmU10s4dmNtHNHUc4HMViMXV3dyuTyYRX3kin0zp6\
# 9KjnlQEA8Grk83n96U9/0g8//LDk/rq6Oo2NjXlaFZ7V2rVr9eabbyoajfpeilkM0CU4evSoDh8+\
# rHQ6ratXr+rIkSMlXcZu48aNL2F1eNnoZg/NbKJbecrn87pz545+9rOfqbq6WpFIJHzs3r17qq6u\
# 9rg6/JRCoaB79+7pm2++kfToHDfPNXecgX5FljtLxDs22UQ3e2hmE93K08TEhN56

# %%
# plt.figure(figsize=(5,9))
# for t in range(0,DURATION, 5):
#     plt.subplot(10, 1, t/5+1)
#     plt.plot(function.index * LENGTH / NUMBER_X, function.iloc[:, int((t) * NUMBER_T / DURATION)],
#                 c='black', lw=2, label=f"${t}$")
    
      
#     plt.legend(loc='upper right')
#     plt.xlabel(r'x')
#     plt.ylabel(r'f(x)')

# plt.subplots_adjust(top=1.4, bottom=0.08, left=0.10, right=0.95, hspace=0.15, wspace=0.2)
