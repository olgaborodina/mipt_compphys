# %% [markdown]
# ## libs

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm_notebook
from tqdm import tqdm_notebook
from matplotlib import animation
from IPython.display import HTML

# %% [markdown]
# ## initialization

# %%
check = 0.75
A = 0.025
LENGTH = 5
DURATION = 100
INITIAL = 0
BOUND = 5

NUMBER_X = 101
NUMBER_T = int(A * DURATION * NUMBER_X / check / LENGTH)

# %%
step_x = LENGTH / (NUMBER_X - 1)
step_t = DURATION / (NUMBER_T - 1)

# %%
axis = np.linspace(0, LENGTH, NUMBER_X)
time = np.linspace(0, DURATION, NUMBER_T)

function = pd.DataFrame(columns = np.concatenate([['x'], time]))

# %%
function['x'] = axis

# %%
function.iloc[:,0] = INITIAL
function.iloc[0] = BOUND
function.iloc[NUMBER_X-1,:] = INITIAL

# %%
def smooth(f, x, t):
    q = 0.4
    dmm = f.iloc[x-1, t+1] - f.iloc[x-2, t+1]
    dm = f.iloc[x, t+1] - f.iloc[x-1, t+1]
    dp = f.iloc[x+1, t+1] - f.iloc[x, t+1]
    dpp = f.iloc[x+2, t+1] - f.iloc[x+1, t+1]
    
    if (dpp * dp < 0) or (dm * dp < 0):
        q_plus = dp
    else:
        q_plus = 0
        
    if (dmm * dm < 0) or (dm * dp < 0):
        q_minus = dm
    else:
        q_minus = 0   
        
    return f.iloc[x, t+1] + q * (q_plus - q_minus)

# %% [markdown]
# ## main procedures

# %%
pbar = tqdm_notebook(total = NUMBER_T)

for t in range(0, NUMBER_T):
    for x in range(1, NUMBER_X - 1):
        f_plus = 0.5 * ((function.iloc[x+1,t] + function.iloc[x,t]) - 
                                      check * (function.iloc[x+1,t] - function.iloc[x,t]))
        
        f_minus = 0.5 * ((function.iloc[x,t] + function.iloc[x-1,t]) - 
                                      check * (function.iloc[x,t] - function.iloc[x-1,t]))
        
        function.iloc[x,t+1] = function.iloc[x,t] - check * (f_plus - f_minus)
    
    for x in range(2, NUMBER_X - 2):
        function.iloc[x, t+1] = smooth(function,x, t)
        
    pbar.update()
# Out:
# HBox(children=(IntProgress(value=0, max=67), HTML(value='')))

# %% [markdown]
# ## animated plot

# %%
plt.rcParams.update({'font.size': 15})
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
plt.rc('text.latex', preamble=r'\usepackage[utf8]{inputenc}')
plt.rc('text.latex', preamble=r'\usepackage[english]{babel}')

fig, ax = plt.subplots(figsize=(10, 5))
ax.axis([-0.1, LENGTH + 0.1, -0.1, BOUND + 1.1])

l1, = ax.plot(function.index * LENGTH / NUMBER_X, function.iloc[:, NUMBER_T], lw=3, color='black', label=NUMBER_T)
l2, = ax.plot([ A * float(function.columns[20]), A * float(function.columns[20])],[0, BOUND], lw=3, color='blue', label=None)

ax.grid(c='#aaaaaa', ls='--')

ax.set_ylabel("f(x)")
ax.set_xlabel("x")

def animate(i):
    l1.set_data(function.index * LENGTH / NUMBER_X, function.iloc[:, i])
    l1.set_label('t = ' + str(i * step_t))
    l2.set_data([A * float(function.columns[i+1]), A * float(function.columns[i+1])],[0, BOUND])

    legend = plt.legend(loc='upper right')
    return l1, l2, legend

ani = animation.FuncAnimation(fig, animate, frames= np.arange(0, NUMBER_T, 10), interval=100)

# ani.save("movie.mp4")
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img6c033d52d7454969a320b2f6e2ff5298">
#     <br>
#     <input id="_anim_slider6c033d52d7454969a320b2f6e2ff5298" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim6c033d52d7454969a320b2f6e2ff5298.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim6c033d52d7454969a320b2f6e2ff5298.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim6c033d52d7454969a320b2f6e2ff5298.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim6c033d52d7454969a320b2f6e2ff5298.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim6c033d52d7454969a320b2f6e2ff5298.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim6c033d52d7454969a320b2f6e2ff5298.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim6c033d52d7454969a320b2f6e2ff5298.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim6c033d52d7454969a320b2f6e2ff5298.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim6c033d52d7454969a320b2f6e2ff5298.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim6c033d52d7454969a320b2f6e2ff5298.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select6c033d52d7454969a320b2f6e2ff5298" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img6c033d52d7454969a320b2f6e2ff5298";
#     var slider_id = "_anim_slider6c033d52d7454969a320b2f6e2ff5298";
#     var loop_select_id = "_anim_loop_select6c033d52d7454969a320b2f6e2ff5298";
#     var frames = new Array(7);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDMuMC4zLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvnQurowAAIABJREFUeJzt3f9OVHme//FX4Y/GCVtTgt1Ar4Nt\
# SWJ0XE0XJRiNRgVuYAb0BnZhLmDbTm92k8lmv2Og+wKasm9ghdn/NxRqNBiVonp1jCzbWFHWbnRa\
# oAZpQVuo/cMvNdL+OgdOeT7v5vlIJlG6KN7jU/Rdx3NORQqFQkEAAAAAPCkLewAAAADAEhZoAAAA\
# wAcWaAAAAMAHFmgAAADABxZoAAAAwAcWaAAAAMAHFmgAAADABxZoAAAAwAcWaAAAAMAHFmgAAADA\
# BxZoAAAAwAcWaAAAAMAHFmgAAADABxZoAAAAwAcWaAAAAMAHFmgAAADABxZoAAAAwAcWaAAAAMAH\
# FmgAAADABxZoAAAAwAcWaAAAAMAHFmgAAADABxZoAAAAwAcWaAAAAMAHFmgAAADABxZoAAAAwAcW\
# aAAAAMAHFmgAAADABxZoAAAAwAcWaAAAAMAHFmgAAADABxZoAAAAwAcWaAAAAMAHFmgAAADABxZo\
# AAAAwAcWaAAAAMAHFmgAAADABxZoAAAAwAcWaAAAAMAHFmgAAADABxZoAAAAwAcWaAAAAMCH9WEP\
# YFU2m1U6nVY8HtfU1JQ6Ojre+PgtW7boo48+8vTcT5480XvvvRfAlCg1WtlBK1voZQet7PDT6s6d\
# O3r48GGJJ7KLBXoFstmsTp8+rd7eXklSQ0ODksmkEonEaz/no48+UiaT8fT8jx8/1i9+8YtAZkVp\
# 0coOWtlCLztoZYefVslkssTT2MYpHCvwD//wD+rq6ir+fGBg4I3Ls1/j4+OBPRdKi1Z20MoWetlB\
# KztoFRwWaJ/y+byy2azi8biy2axyuZxisVigX+PevXuBPh9Kh1Z20MoWetlBKztoFRwWaJ8ymYzi\
# 8bj6+voUj8eVy+XU2dkZ9lgAAAB4RzgH2qd8Pq9cLqeWlhbFYjG1tLSoq6tLfX19amtrW/bYVCql\
# VColSZqYmFA6nZYk1dfXKxqNKpvNSnp+geHevXt17tw5SdLCwoIk6dq1a5qZmZEkNTU16f79+7p7\
# 964kaefOnSovL9f169clSdXV1dq1a5cuXLggSdq4caOOHDmiK1euaHZ2VpJ08OBBjY+PF1+B7t69\
# W2VlZbp586Ykqba2VvX19bp06ZIkadOmTTp06JAGBwc1NzcnSTp8+LDGxsY0MTEhSdqzZ48WFxd1\
# 69YtSdLWrVtVV1eny5cvS5IqKip04MABXbx4UU+fPpUkHT16VCMjI3rw4IEkad++fZqfn9fo6Kgk\
# adu2baqpqdHVq1clSdFoVI2NjTp//nzx1+b48eO6ceNG8QKHRCKhmZkZjY2NSZLi8biqqqo0NDQk\
# Sdq8ebMaGho0MDCgQqGgSCSi5uZmDQ8Pa3p6WpK0f/9+TU5OKpfLeeq0bt067d69m04GOh07dkwb\
# Nmwofg/Syd1OS99PT58+1aNHj+jkeCdJ2r59u7755hs6Od6pqalJsVis+Ofg2zrhzSKFQqEQ9hCW\
# ZLNZNTc3F39TSyoege7p6Xnt5yWTSc8XEd6/f181NTWrGxTvBK3soJUt9LKDVnb4aeVnb1mLOIXD\
# p3g8rnw+/9LHgzwPeukVN9xHKztoZQu97KCVHbQKDqdw+BSLxdTW1qZsNlu880Ymk9GZM2dCngwA\
# APfNzMzoz3/+s3788cewR1lzqqqqNDIyog0bNuiDDz5QNBoNeySzWKBX4MyZMzp9+rQymYxu376t\
# rq6uQG9jV1tbG9hzobRoZQetbKGXHX5azczM6MGDB/rbv/1bbdq0SZFIpIST4afm5uZUXl6uubk5\
# ffvtt5LEEr1CnAP9jvg5l4h3dbKDVnbQyhZ62eGn1djYmD788EPeeCUki4uLKit7f

# %%
# fig, ax = plt.subplots(figsize=(10, 5))
# plt.figure(figsize=(25,15))
# plt.rcParams.update({'font.size': 20})
# plt.rc('text', usetex=True)
# plt.rc('font', family='serif')
# plt.rc('text.latex', preamble=r'\usepackage[utf8]{inputenc}')
# plt.rc('text.latex', preamble=r'\usepackage[english]{babel}')

# ax.plot(function.index * LENGTH / NUMBER_X,function.iloc[:,1001], label="100", c='black')
